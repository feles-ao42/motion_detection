# %%
#!pip install mediapipe
#!pip install tensorflow
#!pip install opencv-python
#!pip install scikit-learn
#!pip install notebook

# %%
# -*- coding: utf-8 -*-
from collections import deque

import cv2
import mediapipe as mp


# ランドマークの画像上の位置を算出する関数
def calc_landmark_list(image, landmarks):
    landmark_point = []
    image_width, image_height = image.shape[1], image.shape[0]

    for _, landmark in enumerate(landmarks.landmark):
        landmark_x = min(int(landmark.x * image_width), image_width - 1)
        landmark_y = min(int(landmark.y * image_height), image_height - 1)
        landmark_point.append([landmark_x, landmark_y])

    return landmark_point


# 座標履歴を描画する関数
def draw_point_history(image, point_history):
    for index, point in enumerate(point_history):
        if point[0] != 0 and point[1] != 0:
            cv2.circle(image, (point[0], point[1]), 1 + int(index / 2),
                       (255, 0, 0), 2)
    return image


# カメラキャプチャ設定
camera_no = 0
video_capture = cv2.VideoCapture(camera_no)
video_capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
video_capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 360)

# MediaPipe Hands初期化
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

hands = mp_hands.Hands(
    max_num_hands=1,  # 最大手検出数：1
    min_detection_confidence=0.5,  # 検出信頼度閾値：0.5
    min_tracking_confidence=0.5  # トラッキング信頼度閾値：0.5
)

# 人差指のID
ID_FINGER_TIP = 9
ID_FINGER_TIP_2 = 12

# 人差指の指先の座標履歴を保持するための変数
history_length = 16
point_history = deque(maxlen=history_length)

while video_capture.isOpened():
    # カメラ画像取得
    ret, frame = video_capture.read()
    if ret is False:
        break

    # 鏡映しになるよう反転
    frame = cv2.flip(frame, 1)

    # MediaPipeで扱う画像は、OpenCVのBGRの並びではなくRGBのため変換
    rgb_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # 画像をリードオンリーにしてHands検出処理実施
    rgb_image.flags.writeable = False
    hands_results = hands.process(rgb_image)
    rgb_image.flags.writeable = True

    # 有効なランドマークが検出された場合、ランドマークを描画
    if hands_results.multi_hand_landmarks:
        for hand_landmarks in hands_results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(frame, hand_landmarks,
                                      mp_hands.HAND_CONNECTIONS)

            # ランドマーク座標の計算
            landmark_list = calc_landmark_list(rgb_image, hand_landmarks)
            # 人差指の指先座標を履歴に追加
            point_history.append(landmark_list[ID_FINGER_TIP])
            point_history.append(landmark_list[ID_FINGER_TIP_2])

    # ディスプレイ表示
    frame = draw_point_history(frame, point_history)
    cv2.imshow('test', frame)

    # キー入力(ESC:プログラム終了)
    key = cv2.waitKey(1)
    if key == 27:  # ESC
        break

# リソースの解放
video_capture.release()
hands.close()
cv2.destroyAllWindows()

# %%
#学習script実行(別ファイル）

# %%
import csv
import copy

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split


dataset = './point_history.csv'
model_save_path = './gesture_classifier.hdf5'


TIME_STEPS = 16
DIMENSION = 2
NUM_CLASSES = 3


X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (TIME_STEPS * DIMENSION) + 1 + 2)))
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

for dataset_index, X_data in enumerate(X_dataset):    
    for data_index in range(0, len(X_data), 2):
        if data_index == 0:
            image_width = X_data[data_index]
            image_height = X_data[data_index + 1]
            continue

        if data_index == 2:
            base_x = X_data[data_index]
            base_y = X_data[data_index + 1]

        X_data[data_index] = (X_data[data_index] - base_x) / image_width
        X_data[data_index + 1] = (X_data[data_index + 1] - base_y) / image_height

X_dataset = np.delete(X_dataset, [0, 1, 2, 3], 1)
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=42)

input_size = (TIME_STEPS * DIMENSION) - 2

model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(input_size, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

model.summary()

# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)


model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)


# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))


# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_3 (Dense)             (None, 24)                744
#
#  dropout_3 (Dropout)         (None, 24)                0
#
#  dense_4 (Dense)             (None, 10)                250
#
#  dense_5 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1,027
# Trainable params: 1,027
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1/5 [=====>........................] - ETA: 4s - loss: 1.0963 - accuracy: 0.2812
# Epoch 1: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 1s 65ms/step - loss: 1.0922 - accuracy: 0.3475 - val_loss: 1.0861 - val_accuracy: 0.5805
# Epoch 2/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0843 - accuracy: 0.5000
# Epoch 2: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0830 - accuracy: 0.5400 - val_loss: 1.0793 - val_accuracy: 0.7122
# Epoch 3/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0814 - accuracy: 0.6094
# Epoch 3: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.0788 - accuracy: 0.6134 - val_loss: 1.0727 - val_accuracy: 0.7512
# Epoch 4/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0650 - accuracy: 0.7422
# Epoch 4: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0688 - accuracy: 0.6835 - val_loss: 1.0662 - val_accuracy: 0.7805
# Epoch 5/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0691 - accuracy: 0.6484
# Epoch 5: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 1.0630 - accuracy: 0.6819 - val_loss: 1.0599 - val_accuracy: 0.8049
# Epoch 6/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0632 - accuracy: 0.5703
# Epoch 6: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.0578 - accuracy: 0.6705 - val_loss: 1.0533 - val_accuracy: 0.8098
# Epoch 7/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0591 - accuracy: 0.7344
# Epoch 7: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.0517 - accuracy: 0.7015 - val_loss: 1.0464 - val_accuracy: 0.8293
# Epoch 8/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0536 - accuracy: 0.7344
# Epoch 8: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.0469 - accuracy: 0.7047 - val_loss: 1.0392 - val_accuracy: 0.8439
# Epoch 9/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0400 - accuracy: 0.6719
# Epoch 9: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.0380 - accuracy: 0.7129 - val_loss: 1.0314 - val_accuracy: 0.8780
# Epoch 10/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0325 - accuracy: 0.6562
# Epoch 10: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0282 - accuracy: 0.7471 - val_loss: 1.0232 - val_accuracy: 0.8878
# Epoch 11/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0150 - accuracy: 0.7734
# Epoch 11: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0209 - accuracy: 0.7537 - val_loss: 1.0148 - val_accuracy: 0.8878
# Epoch 12/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0158 - accuracy: 0.7188
# Epoch 12: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 34ms/step - loss: 1.0150 - accuracy: 0.7488 - val_loss: 1.0059 - val_accuracy: 0.8927
# Epoch 13/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0226 - accuracy: 0.7031
# Epoch 13: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0108 - accuracy: 0.7602 - val_loss: 0.9968 - val_accuracy: 0.9024
# Epoch 14/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9999 - accuracy: 0.7969
# Epoch 14: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9989 - accuracy: 0.7781 - val_loss: 0.9870 - val_accuracy: 0.9073
# Epoch 15/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0036 - accuracy: 0.8125
# Epoch 15: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9877 - accuracy: 0.8026 - val_loss: 0.9766 - val_accuracy: 0.9171
# Epoch 16/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9821 - accuracy: 0.8438
# Epoch 16: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9777 - accuracy: 0.8026 - val_loss: 0.9657 - val_accuracy: 0.9171
# Epoch 17/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9648 - accuracy: 0.7812
# Epoch 17: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9627 - accuracy: 0.8010 - val_loss: 0.9540 - val_accuracy: 0.9122
# Epoch 18/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9662 - accuracy: 0.8281
# Epoch 18: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9559 - accuracy: 0.8173 - val_loss: 0.9417 - val_accuracy: 0.9122
# Epoch 19/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9504 - accuracy: 0.7891
# Epoch 19: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9417 - accuracy: 0.8140 - val_loss: 0.9289 - val_accuracy: 0.9171
# Epoch 20/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9365 - accuracy: 0.7422
# Epoch 20: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9302 - accuracy: 0.8271 - val_loss: 0.9157 - val_accuracy: 0.9122
# Epoch 21/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8969 - accuracy: 0.8672
# Epoch 21: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9197 - accuracy: 0.8140 - val_loss: 0.9021 - val_accuracy: 0.9171
# Epoch 22/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9221 - accuracy: 0.8203
# Epoch 22: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9068 - accuracy: 0.8173 - val_loss: 0.8881 - val_accuracy: 0.9122
# Epoch 23/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8924 - accuracy: 0.8828
# Epoch 23: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8935 - accuracy: 0.8369 - val_loss: 0.8735 - val_accuracy: 0.9122
# Epoch 24/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8822 - accuracy: 0.8438
# Epoch 24: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 11ms/step - loss: 0.8837 - accuracy: 0.8679 - val_loss: 0.8587 - val_accuracy: 0.9122
# Epoch 25/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8954 - accuracy: 0.8438
# Epoch 25: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8665 - accuracy: 0.8483 - val_loss: 0.8437 - val_accuracy: 0.9220
# Epoch 26/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8802 - accuracy: 0.8359
# Epoch 26: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8516 - accuracy: 0.8385 - val_loss: 0.8282 - val_accuracy: 0.9220
# Epoch 27/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8540 - accuracy: 0.8438
# Epoch 27: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8402 - accuracy: 0.8418 - val_loss: 0.8124 - val_accuracy: 0.9220
# Epoch 28/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8470 - accuracy: 0.8203
# Epoch 28: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8296 - accuracy: 0.8613 - val_loss: 0.7959 - val_accuracy: 0.9463
# Epoch 29/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8308 - accuracy: 0.8828
# Epoch 29: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8310 - accuracy: 0.8548 - val_loss: 0.7798 - val_accuracy: 0.9463
# Epoch 30/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7923 - accuracy: 0.8281
# Epoch 30: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8022 - accuracy: 0.8564 - val_loss: 0.7635 - val_accuracy: 0.9463
# Epoch 31/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7570 - accuracy: 0.8828
# Epoch 31: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7831 - accuracy: 0.8744 - val_loss: 0.7464 - val_accuracy: 0.9610
# Epoch 32/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7696 - accuracy: 0.8828
# Epoch 32: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7797 - accuracy: 0.8744 - val_loss: 0.7291 - val_accuracy: 0.9659
# Epoch 33/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7067 - accuracy: 0.9141
# Epoch 33: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7723 - accuracy: 0.8613 - val_loss: 0.7112 - val_accuracy: 0.9707
# Epoch 34/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7664 - accuracy: 0.8125
# Epoch 34: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7462 - accuracy: 0.8597 - val_loss: 0.6939 - val_accuracy: 0.9854
# Epoch 35/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7410 - accuracy: 0.9219
# Epoch 35: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7170 - accuracy: 0.8940 - val_loss: 0.6762 - val_accuracy: 0.9854
# Epoch 36/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7183 - accuracy: 0.9062
# Epoch 36: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7063 - accuracy: 0.9103 - val_loss: 0.6580 - val_accuracy: 0.9854
# Epoch 37/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7330 - accuracy: 0.8594
# Epoch 37: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7062 - accuracy: 0.8874 - val_loss: 0.6401 - val_accuracy: 0.9854
# Epoch 38/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7301 - accuracy: 0.8594
# Epoch 38: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7051 - accuracy: 0.8695 - val_loss: 0.6226 - val_accuracy: 0.9854
# Epoch 39/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7310 - accuracy: 0.8203
# Epoch 39: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6869 - accuracy: 0.8809 - val_loss: 0.6054 - val_accuracy: 0.9902
# Epoch 40/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6445 - accuracy: 0.8906
# Epoch 40: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6588 - accuracy: 0.8940 - val_loss: 0.5884 - val_accuracy: 0.9951
# Epoch 41/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6552 - accuracy: 0.8828
# Epoch 41: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6644 - accuracy: 0.8989 - val_loss: 0.5714 - val_accuracy: 0.9951
# Epoch 42/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6652 - accuracy: 0.9141
# Epoch 42: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6336 - accuracy: 0.8923 - val_loss: 0.5549 - val_accuracy: 0.9951
# Epoch 43/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6086 - accuracy: 0.8984
# Epoch 43: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6241 - accuracy: 0.9086 - val_loss: 0.5389 - val_accuracy: 0.9951
# Epoch 44/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5937 - accuracy: 0.9297
# Epoch 44: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6137 - accuracy: 0.9103 - val_loss: 0.5227 - val_accuracy: 0.9951
# Epoch 45/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6335 - accuracy: 0.8984
# Epoch 45: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5994 - accuracy: 0.9070 - val_loss: 0.5074 - val_accuracy: 0.9951
# Epoch 46/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5824 - accuracy: 0.9297
# Epoch 46: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5749 - accuracy: 0.9233 - val_loss: 0.4926 - val_accuracy: 0.9951
# Epoch 47/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6359 - accuracy: 0.8516
# Epoch 47: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5867 - accuracy: 0.8793 - val_loss: 0.4784 - val_accuracy: 0.9951
# Epoch 48/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5797 - accuracy: 0.9297
# Epoch 48: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5791 - accuracy: 0.9070 - val_loss: 0.4641 - val_accuracy: 0.9951
# Epoch 49/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5770 - accuracy: 0.9062
# Epoch 49: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5668 - accuracy: 0.8940 - val_loss: 0.4505 - val_accuracy: 0.9951
# Epoch 50/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5389 - accuracy: 0.9297
# Epoch 50: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5489 - accuracy: 0.9135 - val_loss: 0.4373 - val_accuracy: 0.9951
# Epoch 51/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5275 - accuracy: 0.8828
# Epoch 51: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5427 - accuracy: 0.8989 - val_loss: 0.4245 - val_accuracy: 0.9951
# Epoch 52/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5319 - accuracy: 0.9297
# Epoch 52: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5158 - accuracy: 0.9250 - val_loss: 0.4120 - val_accuracy: 0.9951
# Epoch 53/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5321 - accuracy: 0.9141
# Epoch 53: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4848 - accuracy: 0.9331 - val_loss: 0.3998 - val_accuracy: 0.9951
# Epoch 54/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5515 - accuracy: 0.9062
# Epoch 54: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5049 - accuracy: 0.9201 - val_loss: 0.3876 - val_accuracy: 0.9951
# Epoch 55/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4959 - accuracy: 0.9141
# Epoch 55: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4827 - accuracy: 0.9266 - val_loss: 0.3760 - val_accuracy: 0.9951
# Epoch 56/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4455 - accuracy: 0.9219
# Epoch 56: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4865 - accuracy: 0.9184 - val_loss: 0.3644 - val_accuracy: 0.9951
# Epoch 57/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4923 - accuracy: 0.9297
# Epoch 57: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4801 - accuracy: 0.9152 - val_loss: 0.3534 - val_accuracy: 0.9951
# Epoch 58/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5146 - accuracy: 0.8906
# Epoch 58: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4778 - accuracy: 0.9201 - val_loss: 0.3423 - val_accuracy: 0.9951
# Epoch 59/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4309 - accuracy: 0.9453
# Epoch 59: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4479 - accuracy: 0.9299 - val_loss: 0.3312 - val_accuracy: 0.9951
# Epoch 60/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4117 - accuracy: 0.9609
# Epoch 60: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4531 - accuracy: 0.9315 - val_loss: 0.3209 - val_accuracy: 0.9951
# Epoch 61/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4489 - accuracy: 0.9297
# Epoch 61: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4380 - accuracy: 0.9315 - val_loss: 0.3115 - val_accuracy: 0.9951
# Epoch 62/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4709 - accuracy: 0.8906
# Epoch 62: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4541 - accuracy: 0.9070 - val_loss: 0.3032 - val_accuracy: 0.9951
# Epoch 63/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4654 - accuracy: 0.9375
# Epoch 63: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4408 - accuracy: 0.9299 - val_loss: 0.2948 - val_accuracy: 0.9951
# Epoch 64/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4070 - accuracy: 0.9219
# Epoch 64: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4232 - accuracy: 0.9201 - val_loss: 0.2866 - val_accuracy: 0.9951
# Epoch 65/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4552 - accuracy: 0.9141
# Epoch 65: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4160 - accuracy: 0.9331 - val_loss: 0.2787 - val_accuracy: 0.9951
# Epoch 66/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3233 - accuracy: 0.9766
# Epoch 66: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4018 - accuracy: 0.9364 - val_loss: 0.2705 - val_accuracy: 0.9951
# Epoch 67/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4361 - accuracy: 0.9141
# Epoch 67: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4056 - accuracy: 0.9299 - val_loss: 0.2627 - val_accuracy: 0.9951
# Epoch 68/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4010 - accuracy: 0.9141
# Epoch 68: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3996 - accuracy: 0.9282 - val_loss: 0.2552 - val_accuracy: 0.9951
# Epoch 69/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3719 - accuracy: 0.9531
# Epoch 69: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3853 - accuracy: 0.9331 - val_loss: 0.2482 - val_accuracy: 0.9951
# Epoch 70/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3673 - accuracy: 0.9219
# Epoch 70: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3714 - accuracy: 0.9331 - val_loss: 0.2415 - val_accuracy: 0.9951
# Epoch 71/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3793 - accuracy: 0.9453
# Epoch 71: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3955 - accuracy: 0.9315 - val_loss: 0.2355 - val_accuracy: 0.9951
# Epoch 72/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3429 - accuracy: 0.9531
# Epoch 72: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3625 - accuracy: 0.9315 - val_loss: 0.2297 - val_accuracy: 0.9951
# Epoch 73/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3982 - accuracy: 0.9375
# Epoch 73: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3475 - accuracy: 0.9478 - val_loss: 0.2239 - val_accuracy: 0.9951
# Epoch 74/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4267 - accuracy: 0.8828
# Epoch 74: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3750 - accuracy: 0.9233 - val_loss: 0.2180 - val_accuracy: 0.9951
# Epoch 75/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3877 - accuracy: 0.9297
# Epoch 75: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3400 - accuracy: 0.9445 - val_loss: 0.2124 - val_accuracy: 0.9951
# Epoch 76/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3876 - accuracy: 0.9219
# Epoch 76: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3493 - accuracy: 0.9396 - val_loss: 0.2068 - val_accuracy: 0.9951
# Epoch 77/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3548 - accuracy: 0.9297
# Epoch 77: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3647 - accuracy: 0.9250 - val_loss: 0.2015 - val_accuracy: 0.9951
# Epoch 78/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3523 - accuracy: 0.9453
# Epoch 78: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3407 - accuracy: 0.9282 - val_loss: 0.1965 - val_accuracy: 0.9951
# Epoch 79/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3188 - accuracy: 0.9453
# Epoch 79: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3261 - accuracy: 0.9315 - val_loss: 0.1916 - val_accuracy: 0.9951
# Epoch 80/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3211 - accuracy: 0.9375
# Epoch 80: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3225 - accuracy: 0.9380 - val_loss: 0.1867 - val_accuracy: 0.9951
# Epoch 81/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2989 - accuracy: 0.9609
# Epoch 81: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3352 - accuracy: 0.9331 - val_loss: 0.1820 - val_accuracy: 0.9951
# Epoch 82/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3217 - accuracy: 0.9219
# Epoch 82: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2988 - accuracy: 0.9478 - val_loss: 0.1774 - val_accuracy: 0.9951
# Epoch 83/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3044 - accuracy: 0.9375
# Epoch 83: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3216 - accuracy: 0.9396 - val_loss: 0.1731 - val_accuracy: 0.9951
# Epoch 84/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2849 - accuracy: 0.9531
# Epoch 84: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3085 - accuracy: 0.9462 - val_loss: 0.1691 - val_accuracy: 0.9951
# Epoch 85/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3018 - accuracy: 0.9375
# Epoch 85: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2815 - accuracy: 0.9625 - val_loss: 0.1650 - val_accuracy: 0.9951
# Epoch 86/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2641 - accuracy: 0.9688
# Epoch 86: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3011 - accuracy: 0.9396 - val_loss: 0.1611 - val_accuracy: 0.9951
# Epoch 87/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3443 - accuracy: 0.9219
# Epoch 87: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3171 - accuracy: 0.9347 - val_loss: 0.1575 - val_accuracy: 0.9951
# Epoch 88/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3293 - accuracy: 0.9375
# Epoch 88: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3177 - accuracy: 0.9217 - val_loss: 0.1543 - val_accuracy: 0.9951
# Epoch 89/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2977 - accuracy: 0.9453
# Epoch 89: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3190 - accuracy: 0.9135 - val_loss: 0.1512 - val_accuracy: 0.9951
# Epoch 90/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2402 - accuracy: 0.9844
# Epoch 90: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2728 - accuracy: 0.9527 - val_loss: 0.1480 - val_accuracy: 0.9951
# Epoch 91/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2545 - accuracy: 0.9688
# Epoch 91: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2646 - accuracy: 0.9511 - val_loss: 0.1443 - val_accuracy: 0.9951
# Epoch 92/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3490 - accuracy: 0.9219
# Epoch 92: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3043 - accuracy: 0.9347 - val_loss: 0.1410 - val_accuracy: 0.9951
# Epoch 93/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3147 - accuracy: 0.8984
# Epoch 93: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2960 - accuracy: 0.9282 - val_loss: 0.1378 - val_accuracy: 0.9951
# Epoch 94/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2675 - accuracy: 0.9531
# Epoch 94: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2743 - accuracy: 0.9429 - val_loss: 0.1346 - val_accuracy: 0.9951
# Epoch 95/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2964 - accuracy: 0.9453
# Epoch 95: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2647 - accuracy: 0.9478 - val_loss: 0.1315 - val_accuracy: 1.0000
# Epoch 96/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2439 - accuracy: 0.9688
# Epoch 96: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2563 - accuracy: 0.9511 - val_loss: 0.1285 - val_accuracy: 1.0000
# Epoch 97/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2704 - accuracy: 0.9375
# Epoch 97: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2504 - accuracy: 0.9478 - val_loss: 0.1257 - val_accuracy: 1.0000
# Epoch 98/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2042 - accuracy: 0.9844
# Epoch 98: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2405 - accuracy: 0.9592 - val_loss: 0.1231 - val_accuracy: 1.0000
# Epoch 99/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2593 - accuracy: 0.9766
# Epoch 99: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2656 - accuracy: 0.9429 - val_loss: 0.1205 - val_accuracy: 1.0000
# Epoch 100/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2501 - accuracy: 0.9688
# Epoch 100: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2686 - accuracy: 0.9413 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 101/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2455 - accuracy: 0.9531
# Epoch 101: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2384 - accuracy: 0.9527 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 102/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2338 - accuracy: 0.9609
# Epoch 102: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2541 - accuracy: 0.9380 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 103/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2330 - accuracy: 0.9688
# Epoch 103: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2358 - accuracy: 0.9543 - val_loss: 0.1108 - val_accuracy: 1.0000
# Epoch 104/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2608 - accuracy: 0.9375
# Epoch 104: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2439 - accuracy: 0.9429 - val_loss: 0.1084 - val_accuracy: 1.0000
# Epoch 105/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2360 - accuracy: 0.9375
# Epoch 105: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2504 - accuracy: 0.9396 - val_loss: 0.1063 - val_accuracy: 1.0000
# Epoch 106/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2410 - accuracy: 0.9297
# Epoch 106: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2399 - accuracy: 0.9413 - val_loss: 0.1042 - val_accuracy: 1.0000
# Epoch 107/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3020 - accuracy: 0.9062
# Epoch 107: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2488 - accuracy: 0.9331 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 108/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2819 - accuracy: 0.9219
# Epoch 108: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2338 - accuracy: 0.9478 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 109/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2089 - accuracy: 0.9766
# Epoch 109: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2293 - accuracy: 0.9527 - val_loss: 0.0982 - val_accuracy: 1.0000
# Epoch 110/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2229 - accuracy: 0.9453
# Epoch 110: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2529 - accuracy: 0.9282 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 111/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2219 - accuracy: 0.9453
# Epoch 111: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2097 - accuracy: 0.9543 - val_loss: 0.0946 - val_accuracy: 1.0000
# Epoch 112/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2571 - accuracy: 0.9219
# Epoch 112: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2533 - accuracy: 0.9315 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 113/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2379 - accuracy: 0.9375
# Epoch 113: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2575 - accuracy: 0.9282 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 114/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2411 - accuracy: 0.9453
# Epoch 114: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2251 - accuracy: 0.9478 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 115/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2828 - accuracy: 0.9297
# Epoch 115: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2333 - accuracy: 0.9347 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 116/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2401 - accuracy: 0.9375
# Epoch 116: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2124 - accuracy: 0.9527 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 117/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2232 - accuracy: 0.9375
# Epoch 117: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1953 - accuracy: 0.9576 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 118/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2100 - accuracy: 0.9375
# Epoch 118: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1956 - accuracy: 0.9560 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 119/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2106 - accuracy: 0.9453
# Epoch 119: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2153 - accuracy: 0.9445 - val_loss: 0.0820 - val_accuracy: 1.0000
# Epoch 120/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1515 - accuracy: 0.9688
# Epoch 120: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2039 - accuracy: 0.9543 - val_loss: 0.0804 - val_accuracy: 1.0000
# Epoch 121/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2208 - accuracy: 0.9375
# Epoch 121: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2295 - accuracy: 0.9364 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 122/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1886 - accuracy: 0.9609
# Epoch 122: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1837 - accuracy: 0.9641 - val_loss: 0.0776 - val_accuracy: 1.0000
# Epoch 123/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1775 - accuracy: 0.9688
# Epoch 123: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1939 - accuracy: 0.9560 - val_loss: 0.0764 - val_accuracy: 1.0000
# Epoch 124/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2001 - accuracy: 0.9531
# Epoch 124: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1864 - accuracy: 0.9576 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 125/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1769 - accuracy: 0.9609
# Epoch 125: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1887 - accuracy: 0.9527 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 126/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2247 - accuracy: 0.9375
# Epoch 126: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1892 - accuracy: 0.9576 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 127/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1448 - accuracy: 0.9688
# Epoch 127: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1810 - accuracy: 0.9576 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 128/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1919 - accuracy: 0.9531
# Epoch 128: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1977 - accuracy: 0.9462 - val_loss: 0.0698 - val_accuracy: 1.0000
# Epoch 129/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2105 - accuracy: 0.9531
# Epoch 129: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2129 - accuracy: 0.9429 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 130/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2037 - accuracy: 0.9375
# Epoch 130: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1834 - accuracy: 0.9576 - val_loss: 0.0678 - val_accuracy: 1.0000
# Epoch 131/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2444 - accuracy: 0.9219
# Epoch 131: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1875 - accuracy: 0.9511 - val_loss: 0.0668 - val_accuracy: 1.0000
# Epoch 132/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1919 - accuracy: 0.9375
# Epoch 132: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2257 - accuracy: 0.9380 - val_loss: 0.0659 - val_accuracy: 1.0000
# Epoch 133/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1169 - accuracy: 0.9844
# Epoch 133: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1597 - accuracy: 0.9625 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 134/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2232 - accuracy: 0.9375
# Epoch 134: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1992 - accuracy: 0.9380 - val_loss: 0.0633 - val_accuracy: 1.0000
# Epoch 135/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1696 - accuracy: 0.9688
# Epoch 135: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1658 - accuracy: 0.9625 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 136/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1638 - accuracy: 0.9922
# Epoch 136: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1722 - accuracy: 0.9674 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 137/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1894 - accuracy: 0.9531
# Epoch 137: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2204 - accuracy: 0.9331 - val_loss: 0.0604 - val_accuracy: 1.0000
# Epoch 138/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2251 - accuracy: 0.9453
# Epoch 138: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1733 - accuracy: 0.9560 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 139/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1457 - accuracy: 0.9609
# Epoch 139: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1822 - accuracy: 0.9462 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 140/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1648 - accuracy: 0.9688
# Epoch 140: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1956 - accuracy: 0.9429 - val_loss: 0.0578 - val_accuracy: 1.0000
# Epoch 141/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2850 - accuracy: 0.9141
# Epoch 141: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1735 - accuracy: 0.9625 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 142/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2301 - accuracy: 0.9297
# Epoch 142: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1630 - accuracy: 0.9641 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 143/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1630 - accuracy: 0.9609
# Epoch 143: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1641 - accuracy: 0.9608 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 144/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1933 - accuracy: 0.9297
# Epoch 144: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1799 - accuracy: 0.9527 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 145/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1988 - accuracy: 0.9453
# Epoch 145: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1849 - accuracy: 0.9494 - val_loss: 0.0537 - val_accuracy: 1.0000
# Epoch 146/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2083 - accuracy: 0.9453
# Epoch 146: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1807 - accuracy: 0.9478 - val_loss: 0.0529 - val_accuracy: 1.0000
# Epoch 147/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1961 - accuracy: 0.9453
# Epoch 147: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1596 - accuracy: 0.9641 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 148/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1400 - accuracy: 0.9609
# Epoch 148: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1597 - accuracy: 0.9608 - val_loss: 0.0515 - val_accuracy: 1.0000
# Epoch 149/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1656 - accuracy: 0.9609
# Epoch 149: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1507 - accuracy: 0.9625 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 150/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1929 - accuracy: 0.9375
# Epoch 150: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1720 - accuracy: 0.9543 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 151/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2345 - accuracy: 0.9141
# Epoch 151: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1798 - accuracy: 0.9364 - val_loss: 0.0496 - val_accuracy: 1.0000
# Epoch 152/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1345 - accuracy: 0.9688
# Epoch 152: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1455 - accuracy: 0.9657 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 153/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1322 - accuracy: 0.9766
# Epoch 153: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1322 - accuracy: 0.9706 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 154/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1862 - accuracy: 0.9688
# Epoch 154: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1855 - accuracy: 0.9478 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 155/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1436 - accuracy: 0.9688
# Epoch 155: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1544 - accuracy: 0.9592 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 156/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2040 - accuracy: 0.9375
# Epoch 156: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1962 - accuracy: 0.9445 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 157/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1900 - accuracy: 0.9375
# Epoch 157: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1615 - accuracy: 0.9608 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 158/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1263 - accuracy: 0.9688
# Epoch 158: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1802 - accuracy: 0.9429 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 159/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1817 - accuracy: 0.9531
# Epoch 159: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1738 - accuracy: 0.9478 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 160/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1685 - accuracy: 0.9453
# Epoch 160: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1601 - accuracy: 0.9511 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 161/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1565 - accuracy: 0.9531
# Epoch 161: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1810 - accuracy: 0.9462 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 162/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1790 - accuracy: 0.9531
# Epoch 162: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1584 - accuracy: 0.9608 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 163/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1399 - accuracy: 0.9688
# Epoch 163: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1627 - accuracy: 0.9527 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 164/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1859 - accuracy: 0.9453
# Epoch 164: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1565 - accuracy: 0.9592 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 165/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1006 - accuracy: 0.9922
# Epoch 165: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1469 - accuracy: 0.9625 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 166/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1234 - accuracy: 0.9844
# Epoch 166: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1282 - accuracy: 0.9755 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 167/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1963 - accuracy: 0.9531
# Epoch 167: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1217 - accuracy: 0.9739 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 168/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1514 - accuracy: 0.9609
# Epoch 168: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1420 - accuracy: 0.9641 - val_loss: 0.0399 - val_accuracy: 1.0000
# Epoch 169/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2070 - accuracy: 0.9453
# Epoch 169: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1768 - accuracy: 0.9494 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 170/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2393 - accuracy: 0.9219
# Epoch 170: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1801 - accuracy: 0.9445 - val_loss: 0.0393 - val_accuracy: 1.0000
# Epoch 171/1000
# ...
# Epoch 422/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0923 - accuracy: 0.9609
# Epoch 422: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0790 - accuracy: 0.9755 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 423/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0336 - accuracy: 0.9922
# Epoch 423: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0777 - accuracy: 0.9723 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 424/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0756 - accuracy: 0.9688
# Epoch 424: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0926 - accuracy: 0.9657 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 425/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1189 - accuracy: 0.9766
# Epoch 425: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0666 - accuracy: 0.9869 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 426/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1380 - accuracy: 0.9453
# Epoch 426: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0978 - accuracy: 0.9641 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 427/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0698 - accuracy: 0.9766
# Epoch 427: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0911 - accuracy: 0.9706 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 428/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0898 - accuracy: 0.9609
# Epoch 428: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0906 - accuracy: 0.9625 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 429/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0775 - accuracy: 0.9766
# Epoch 429: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1016 - accuracy: 0.9674 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 430/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1302 - accuracy: 0.9453
# Epoch 430: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0935 - accuracy: 0.9706 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 431/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1286 - accuracy: 0.9609
# Epoch 431: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1116 - accuracy: 0.9641 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 432/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0864 - accuracy: 0.9688
# Epoch 432: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0846 - accuracy: 0.9723 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 433/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0981 - accuracy: 0.9688
# Epoch 433: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1127 - accuracy: 0.9608 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 434/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0918 - accuracy: 0.9609
# Epoch 434: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0915 - accuracy: 0.9690 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 435/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1131 - accuracy: 0.9688
# Epoch 435: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1045 - accuracy: 0.9657 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 436/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0495 - accuracy: 0.9844
# Epoch 436: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0614 - accuracy: 0.9772 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 437/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1436 - accuracy: 0.9453
# Epoch 437: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1066 - accuracy: 0.9641 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 438/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0787 - accuracy: 0.9766
# Epoch 438: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1045 - accuracy: 0.9657 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 439/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0581 - accuracy: 0.9844
# Epoch 439: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1204 - accuracy: 0.9543 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 440/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1115 - accuracy: 0.9609
# Epoch 440: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0936 - accuracy: 0.9690 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 441/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1115 - accuracy: 0.9609
# Epoch 441: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1181 - accuracy: 0.9625 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 442/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0936 - accuracy: 0.9688
# Epoch 442: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1126 - accuracy: 0.9625 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 443/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0715 - accuracy: 0.9844
# Epoch 443: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1181 - accuracy: 0.9592 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 444/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1148 - accuracy: 0.9688
# Epoch 444: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1049 - accuracy: 0.9739 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 445/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0554 - accuracy: 0.9844
# Epoch 445: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0932 - accuracy: 0.9706 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 446/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0878 - accuracy: 0.9688
# Epoch 446: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0889 - accuracy: 0.9625 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 447/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1380 - accuracy: 0.9453
# Epoch 447: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0988 - accuracy: 0.9641 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 448/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1253 - accuracy: 0.9609
# Epoch 448: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1029 - accuracy: 0.9674 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 449/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1430 - accuracy: 0.9375
# Epoch 449: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1118 - accuracy: 0.9641 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 450/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0874 - accuracy: 0.9766
# Epoch 450: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0700 - accuracy: 0.9772 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 451/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1174 - accuracy: 0.9609
# Epoch 451: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1134 - accuracy: 0.9592 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 452/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0804 - accuracy: 0.9844
# Epoch 452: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0923 - accuracy: 0.9723 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 453/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0853 - accuracy: 0.9766
# Epoch 453: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1071 - accuracy: 0.9641 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 454/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0771 - accuracy: 0.9766
# Epoch 454: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0923 - accuracy: 0.9723 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 455/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0488 - accuracy: 0.9844
# Epoch 455: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0822 - accuracy: 0.9788 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 456/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0870 - accuracy: 0.9766
# Epoch 456: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0767 - accuracy: 0.9804 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 457/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1021 - accuracy: 0.9688
# Epoch 457: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0925 - accuracy: 0.9706 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 458/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0647 - accuracy: 0.9688
# Epoch 458: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0956 - accuracy: 0.9674 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 459/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1364 - accuracy: 0.9688
# Epoch 459: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1407 - accuracy: 0.9494 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 460/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0966 - accuracy: 0.9531
# Epoch 460: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0703 - accuracy: 0.9772 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 461/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0255 - accuracy: 1.0000
# Epoch 461: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0971 - accuracy: 0.9674 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 462/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1427 - accuracy: 0.9609
# Epoch 462: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0950 - accuracy: 0.9706 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 463/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1296 - accuracy: 0.9609
# Epoch 463: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1136 - accuracy: 0.9625 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 464/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0658 - accuracy: 0.9688
# Epoch 464: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0925 - accuracy: 0.9625 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 465/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0648 - accuracy: 0.9844
# Epoch 465: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1283 - accuracy: 0.9478 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 466/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1463 - accuracy: 0.9453
# Epoch 466: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0909 - accuracy: 0.9674 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 467/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0770 - accuracy: 0.9688
# Epoch 467: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1072 - accuracy: 0.9657 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 468/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1268 - accuracy: 0.9609
# Epoch 468: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1190 - accuracy: 0.9625 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 469/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0743 - accuracy: 0.9844
# Epoch 469: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0964 - accuracy: 0.9706 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 470/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0842 - accuracy: 0.9688
# Epoch 470: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0984 - accuracy: 0.9641 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 471/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1091 - accuracy: 0.9688
# Epoch 471: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0910 - accuracy: 0.9739 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 472/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0930 - accuracy: 0.9766
# Epoch 472: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1168 - accuracy: 0.9592 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 473/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0643 - accuracy: 0.9688
# Epoch 473: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0841 - accuracy: 0.9723 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 474/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1478 - accuracy: 0.9375
# Epoch 474: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0825 - accuracy: 0.9674 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 475/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1103 - accuracy: 0.9531
# Epoch 475: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1341 - accuracy: 0.9527 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 476/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1340 - accuracy: 0.9609
# Epoch 476: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1005 - accuracy: 0.9657 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 477/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0949 - accuracy: 0.9766
# Epoch 477: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0948 - accuracy: 0.9674 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 478/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0798 - accuracy: 0.9766
# Epoch 478: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0717 - accuracy: 0.9804 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 478: early stopping
# 1/1 [==============================] - 0s 64ms/step
# [0.9676733  0.01477591 0.01755081]
# 0

# %%
print(model_save_path)
# Out:
# ./gesture_classifier.hdf5

# %%
model = tf.keras.models.load_model(model_save_path)
tflite_save_path = './gesture_classifier.tflite'

# モデルを変換(量子化)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)

interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = tf.keras.models.load_model(model_save_path)
#       2 tflite_save_path = './gesture_classifier.tflite'
#       4 # モデルを変換(量子化)
#
# File ~\anaconda3\lib\site-packages\keras\saving\saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\lib\io\file_io.py:703, in is_directory_v2(path)
#     694 """Returns whether the path is a directory or not.
#     695
#     696 Args:
#    (...)
#     700   True, if the path is a directory; False otherwise
#     701 """
#     702 try:
# --> 703   return _pywrap_file_io.IsDirectory(compat.path_to_bytes(path))
#     704 except errors.OpError:
#     705   return False
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe5 in position 30: invalid continuation byte

# %%
# chapter06.py
# -*- coding: utf-8 -*-
import csv
import copy
import itertools
from collections import deque

import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf


# ランドマークの画像上の位置を算出する関数
def calc_landmark_list(image, landmarks):
    landmark_point = []
    image_width, image_height = image.shape[1], image.shape[0]

    for _, landmark in enumerate(landmarks.landmark):
        landmark_x = min(int(landmark.x * image_width), image_width - 1)
        landmark_y = min(int(landmark.y * image_height), image_height - 1)
        landmark_point.append([landmark_x, landmark_y])

    return landmark_point


# 座標履歴を描画する関数
def draw_point_history(image, point_history):
    for index, point in enumerate(point_history):
        if point[0] != 0 and point[1] != 0:
            cv2.circle(image, (point[0], point[1]), 1 + int(index / 2),
                       (255, 0, 0), 2)
    return image


def pre_process_point_history(image, point_history):
    image_width, image_height = image.shape[1], image.shape[0]

    temp_point_history = copy.deepcopy(point_history)

    # 相対座標に変換
    base_x, base_y = 0, 0
    for index, point in enumerate(temp_point_history):
        if index == 0:
            base_x, base_y = point[0], point[1]

        temp_point_history[index][0] = (temp_point_history[index][0] -
                                        base_x) / image_width
        temp_point_history[index][1] = (temp_point_history[index][1] -
                                        base_y) / image_height

    # 1次元リストに変換
    temp_point_history = list(
        itertools.chain.from_iterable(temp_point_history))

    del temp_point_history[0:2]

    return temp_point_history


# カメラキャプチャ設定
camera_no = 0
video_capture = cv2.VideoCapture(camera_no)
video_capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
video_capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 360)

# MediaPipe Hands初期化
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

hands = mp_hands.Hands(
    max_num_hands=1,  # 最大手検出数：1
    min_detection_confidence=0.5,  # 検出信頼度閾値：0.5
    min_tracking_confidence=0.5  # トラッキング信頼度閾値：0.5
)

# ジェスチャー認識用モデルロード
tflite_save_path = './gesture_classifier.tflite'
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# 人差指のID
ID_FINGER_TIP = 8

# 人差指の指先の座標履歴を保持するための変数
history_length = 16
point_history = deque(maxlen=history_length)
gesture_label = ['Stop', 'Clockwise', 'Counter Clockwise']

while video_capture.isOpened():
    # カメラ画像取得
    ret, frame = video_capture.read()
    if ret is False:
        break
    frame_width, frame_height = frame.shape[1], frame.shape[0]

    # 鏡映しになるよう反転
    frame = cv2.flip(frame, 1)

    # MediaPipeで扱う画像は、OpenCVのBGRの並びではなくRGBのため変換
    rgb_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # 画像をリードオンリーにしてHands検出処理実施
    rgb_image.flags.writeable = False
    hands_results = hands.process(rgb_image)
    rgb_image.flags.writeable = True

    # 有効なランドマークが検出された場合、ランドマークを描画
    if hands_results.multi_hand_landmarks:
        for hand_landmarks in hands_results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(frame, hand_landmarks,
                                      mp_hands.HAND_CONNECTIONS)

            # ランドマーク座標の計算
            landmark_list = calc_landmark_list(rgb_image, hand_landmarks)
            # 人差指の指先座標を履歴に追加
            point_history.append(landmark_list[ID_FINGER_TIP])
    else:
        if len(point_history) > 0:
            point_history.popleft()

    gesture_id = 0
    if len(point_history) == history_length:
        temp_point_history = pre_process_point_history(rgb_image,
                                                       point_history)

        interpreter.set_tensor(
            input_details[0]['index'],
            np.array([temp_point_history]).astype(np.float32))
        interpreter.invoke()
        tflite_results = interpreter.get_tensor(output_details[0]['index'])

        gesture_id = np.argmax(np.squeeze(tflite_results))

    # ディスプレイ表示
    cv2.putText(frame, gesture_label[gesture_id], (10, 30),
                cv2.FONT_HERSHEY_PLAIN, 1.2, (255, 0, 0), 1, cv2.LINE_AA)
    frame = draw_point_history(frame, point_history)
    cv2.imshow('chapter06', frame)

    # キー入力(ESC:プログラム終了)
    key = cv2.waitKey(1)
    if key == 27:  # ESC
        break

# リソースの解放
video_capture.release()
hands.close()
cv2.destroyAllWindows()
