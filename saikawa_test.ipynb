# %%
#!pip install mediapipe
#!pip install tensorflow
#!pip install opencv-python
#!pip install scikit-learn
#!pip install notebook

# %%
# -*- coding: utf-8 -*-
from collections import deque

import cv2
import mediapipe as mp


# ランドマークの画像上の位置を算出する関数
def calc_landmark_list(image, landmarks):
    landmark_point = []
    image_width, image_height = image.shape[1], image.shape[0]

    for _, landmark in enumerate(landmarks.landmark):
        landmark_x = min(int(landmark.x * image_width), image_width - 1)
        landmark_y = min(int(landmark.y * image_height), image_height - 1)
        landmark_point.append([landmark_x, landmark_y])

    return landmark_point


# 座標履歴を描画する関数
def draw_point_history(image, point_history):
    for index, point in enumerate(point_history):
        if point[0] != 0 and point[1] != 0:
            cv2.circle(image, (point[0], point[1]), 1 + int(index / 2),
                       (255, 0, 0), 2)
    return image


# カメラキャプチャ設定
camera_no = 0
video_capture = cv2.VideoCapture(camera_no)
video_capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
video_capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 360)

# MediaPipe Hands初期化
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

hands = mp_hands.Hands(
    max_num_hands=1,  # 最大手検出数：1
    min_detection_confidence=0.5,  # 検出信頼度閾値：0.5
    min_tracking_confidence=0.5  # トラッキング信頼度閾値：0.5
)

# 人差指のID
ID_FINGER_TIP = 8

# 人差指の指先の座標履歴を保持するための変数
history_length = 16
point_history = deque(maxlen=history_length)

while video_capture.isOpened():
    # カメラ画像取得
    ret, frame = video_capture.read()
    if ret is False:
        break

    # 鏡映しになるよう反転
    frame = cv2.flip(frame, 1)

    # MediaPipeで扱う画像は、OpenCVのBGRの並びではなくRGBのため変換
    rgb_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # 画像をリードオンリーにしてHands検出処理実施
    rgb_image.flags.writeable = False
    hands_results = hands.process(rgb_image)
    rgb_image.flags.writeable = True

    # 有効なランドマークが検出された場合、ランドマークを描画
    if hands_results.multi_hand_landmarks:
        for hand_landmarks in hands_results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(frame, hand_landmarks,
                                      mp_hands.HAND_CONNECTIONS)

            # ランドマーク座標の計算
            landmark_list = calc_landmark_list(rgb_image, hand_landmarks)
            # 人差指の指先座標を履歴に追加
            point_history.append(landmark_list[ID_FINGER_TIP])

    # ディスプレイ表示
    frame = draw_point_history(frame, point_history)
    cv2.imshow('test', frame)

    # キー入力(ESC:プログラム終了)
    key = cv2.waitKey(1)
    if key == 27:  # ESC
        break

# リソースの解放
video_capture.release()
hands.close()
cv2.destroyAllWindows()

# %%
#学習script実行(別ファイル）

# %%
import csv
import copy

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split


dataset = './point_history.csv'
model_save_path = './gesture_classifier.hdf5'


TIME_STEPS = 16
DIMENSION = 2
NUM_CLASSES = 3


X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (TIME_STEPS * DIMENSION) + 1 + 2)))
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

for dataset_index, X_data in enumerate(X_dataset):    
    for data_index in range(0, len(X_data), 2):
        if data_index == 0:
            image_width = X_data[data_index]
            image_height = X_data[data_index + 1]
            continue

        if data_index == 2:
            base_x = X_data[data_index]
            base_y = X_data[data_index + 1]

        X_data[data_index] = (X_data[data_index] - base_x) / image_width
        X_data[data_index + 1] = (X_data[data_index + 1] - base_y) / image_height

X_dataset = np.delete(X_dataset, [0, 1, 2, 3], 1)
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=42)

input_size = (TIME_STEPS * DIMENSION) - 2

model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(input_size, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

model.summary()

# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)


model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)


# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))


# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_3 (Dense)             (None, 24)                744
#
#  dropout_3 (Dropout)         (None, 24)                0
#
#  dense_4 (Dense)             (None, 10)                250
#
#  dense_5 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 1,027
# Trainable params: 1,027
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 1/5 [=====>........................] - ETA: 3s - loss: 1.1002 - accuracy: 0.3203
# Epoch 1: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 1s 76ms/step - loss: 1.0970 - accuracy: 0.3850 - val_loss: 1.0883 - val_accuracy: 0.6049
# Epoch 2/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0870 - accuracy: 0.5703
# Epoch 2: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 33ms/step - loss: 1.0922 - accuracy: 0.6052 - val_loss: 1.0804 - val_accuracy: 0.6829
# Epoch 3/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0877 - accuracy: 0.6094
# Epoch 3: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0827 - accuracy: 0.6297 - val_loss: 1.0736 - val_accuracy: 0.6829
# Epoch 4/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0709 - accuracy: 0.7109
# Epoch 4: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 1.0759 - accuracy: 0.6803 - val_loss: 1.0677 - val_accuracy: 0.6976
# Epoch 5/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0762 - accuracy: 0.6328
# Epoch 5: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 1.0725 - accuracy: 0.6623 - val_loss: 1.0625 - val_accuracy: 0.7073
# Epoch 6/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0692 - accuracy: 0.6875
# Epoch 6: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0602 - accuracy: 0.7455 - val_loss: 1.0573 - val_accuracy: 0.7220
# Epoch 7/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0624 - accuracy: 0.7109
# Epoch 7: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0621 - accuracy: 0.6868 - val_loss: 1.0519 - val_accuracy: 0.7220
# Epoch 8/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0476 - accuracy: 0.7578
# Epoch 8: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0558 - accuracy: 0.6982 - val_loss: 1.0461 - val_accuracy: 0.7268
# Epoch 9/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0524 - accuracy: 0.7188
# Epoch 9: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 1.0515 - accuracy: 0.7031 - val_loss: 1.0403 - val_accuracy: 0.7463
# Epoch 10/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0360 - accuracy: 0.7578
# Epoch 10: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0358 - accuracy: 0.7504 - val_loss: 1.0339 - val_accuracy: 0.7512
# Epoch 11/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0356 - accuracy: 0.7422
# Epoch 11: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0361 - accuracy: 0.7178 - val_loss: 1.0271 - val_accuracy: 0.7561
# Epoch 12/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0142 - accuracy: 0.7656
# Epoch 12: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0289 - accuracy: 0.7406 - val_loss: 1.0197 - val_accuracy: 0.7707
# Epoch 13/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0243 - accuracy: 0.7734
# Epoch 13: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0208 - accuracy: 0.7553 - val_loss: 1.0119 - val_accuracy: 0.7902
# Epoch 14/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0157 - accuracy: 0.7500
# Epoch 14: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 1.0144 - accuracy: 0.7537 - val_loss: 1.0036 - val_accuracy: 0.8000
# Epoch 15/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0150 - accuracy: 0.7266
# Epoch 15: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 1.0071 - accuracy: 0.7357 - val_loss: 0.9947 - val_accuracy: 0.8146
# Epoch 16/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9837 - accuracy: 0.7812
# Epoch 16: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9978 - accuracy: 0.7765 - val_loss: 0.9851 - val_accuracy: 0.8195
# Epoch 17/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0057 - accuracy: 0.6719
# Epoch 17: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9914 - accuracy: 0.7635 - val_loss: 0.9746 - val_accuracy: 0.8293
# Epoch 18/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9712 - accuracy: 0.7500
# Epoch 18: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.9827 - accuracy: 0.7488 - val_loss: 0.9636 - val_accuracy: 0.8439
# Epoch 19/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9572 - accuracy: 0.8438
# Epoch 19: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9656 - accuracy: 0.8059 - val_loss: 0.9519 - val_accuracy: 0.8537
# Epoch 20/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9770 - accuracy: 0.7578
# Epoch 20: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9557 - accuracy: 0.7863 - val_loss: 0.9392 - val_accuracy: 0.8585
# Epoch 21/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9377 - accuracy: 0.8047
# Epoch 21: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9438 - accuracy: 0.7945 - val_loss: 0.9252 - val_accuracy: 0.8683
# Epoch 22/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9376 - accuracy: 0.8125
# Epoch 22: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9277 - accuracy: 0.7977 - val_loss: 0.9108 - val_accuracy: 0.8927
# Epoch 23/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9286 - accuracy: 0.7891
# Epoch 23: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.9246 - accuracy: 0.7896 - val_loss: 0.8959 - val_accuracy: 0.9073
# Epoch 24/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9237 - accuracy: 0.7734
# Epoch 24: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9100 - accuracy: 0.8010 - val_loss: 0.8792 - val_accuracy: 0.9268
# Epoch 25/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8750 - accuracy: 0.8047
# Epoch 25: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8922 - accuracy: 0.8140 - val_loss: 0.8618 - val_accuracy: 0.9561
# Epoch 26/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8852 - accuracy: 0.8359
# Epoch 26: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.8672 - accuracy: 0.8271 - val_loss: 0.8445 - val_accuracy: 0.9756
# Epoch 27/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8781 - accuracy: 0.8125
# Epoch 27: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.8778 - accuracy: 0.8075 - val_loss: 0.8268 - val_accuracy: 0.9805
# Epoch 28/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8682 - accuracy: 0.8906
# Epoch 28: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8449 - accuracy: 0.8499 - val_loss: 0.8089 - val_accuracy: 0.9902
# Epoch 29/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8415 - accuracy: 0.8281
# Epoch 29: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8410 - accuracy: 0.8222 - val_loss: 0.7909 - val_accuracy: 0.9951
# Epoch 30/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7969 - accuracy: 0.8438
# Epoch 30: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.8274 - accuracy: 0.8254 - val_loss: 0.7721 - val_accuracy: 1.0000
# Epoch 31/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8110 - accuracy: 0.7969
# Epoch 31: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.8010 - accuracy: 0.8515 - val_loss: 0.7535 - val_accuracy: 0.9951
# Epoch 32/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7948 - accuracy: 0.8594
# Epoch 32: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 34ms/step - loss: 0.8024 - accuracy: 0.8467 - val_loss: 0.7345 - val_accuracy: 0.9951
# Epoch 33/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7936 - accuracy: 0.8281
# Epoch 33: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7714 - accuracy: 0.8581 - val_loss: 0.7149 - val_accuracy: 0.9951
# Epoch 34/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7869 - accuracy: 0.8281
# Epoch 34: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7581 - accuracy: 0.8581 - val_loss: 0.6949 - val_accuracy: 0.9951
# Epoch 35/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7555 - accuracy: 0.8438
# Epoch 35: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7464 - accuracy: 0.8532 - val_loss: 0.6750 - val_accuracy: 0.9951
# Epoch 36/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7091 - accuracy: 0.8906
# Epoch 36: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7081 - accuracy: 0.8793 - val_loss: 0.6558 - val_accuracy: 0.9951
# Epoch 37/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7325 - accuracy: 0.8281
# Epoch 37: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7136 - accuracy: 0.8630 - val_loss: 0.6355 - val_accuracy: 0.9951
# Epoch 38/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7200 - accuracy: 0.8359
# Epoch 38: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7030 - accuracy: 0.8613 - val_loss: 0.6156 - val_accuracy: 0.9951
# Epoch 39/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6878 - accuracy: 0.8438
# Epoch 39: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6927 - accuracy: 0.8515 - val_loss: 0.5958 - val_accuracy: 0.9951
# Epoch 40/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6820 - accuracy: 0.8750
# Epoch 40: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6668 - accuracy: 0.8923 - val_loss: 0.5768 - val_accuracy: 0.9951
# Epoch 41/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6770 - accuracy: 0.8438
# Epoch 41: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6682 - accuracy: 0.8499 - val_loss: 0.5576 - val_accuracy: 0.9951
# Epoch 42/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6297 - accuracy: 0.8750
# Epoch 42: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6427 - accuracy: 0.8679 - val_loss: 0.5405 - val_accuracy: 0.9951
# Epoch 43/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6694 - accuracy: 0.8359
# Epoch 43: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6227 - accuracy: 0.8679 - val_loss: 0.5232 - val_accuracy: 0.9951
# Epoch 44/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.6188 - accuracy: 0.8750
# Epoch 44: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6100 - accuracy: 0.8711 - val_loss: 0.5056 - val_accuracy: 0.9951
# Epoch 45/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5927 - accuracy: 0.8750
# Epoch 45: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5928 - accuracy: 0.8858 - val_loss: 0.4879 - val_accuracy: 0.9951
# Epoch 46/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5930 - accuracy: 0.8281
# Epoch 46: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5850 - accuracy: 0.8809 - val_loss: 0.4697 - val_accuracy: 0.9951
# Epoch 47/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5842 - accuracy: 0.8984
# Epoch 47: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5769 - accuracy: 0.8809 - val_loss: 0.4511 - val_accuracy: 0.9951
# Epoch 48/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5653 - accuracy: 0.8984
# Epoch 48: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5294 - accuracy: 0.9119 - val_loss: 0.4333 - val_accuracy: 0.9951
# Epoch 49/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5255 - accuracy: 0.8984
# Epoch 49: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5553 - accuracy: 0.8760 - val_loss: 0.4162 - val_accuracy: 0.9951
# Epoch 50/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5512 - accuracy: 0.8828
# Epoch 50: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5196 - accuracy: 0.8874 - val_loss: 0.4000 - val_accuracy: 0.9951
# Epoch 51/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5327 - accuracy: 0.8672
# Epoch 51: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5176 - accuracy: 0.8907 - val_loss: 0.3837 - val_accuracy: 0.9951
# Epoch 52/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4820 - accuracy: 0.9375
# Epoch 52: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5017 - accuracy: 0.9038 - val_loss: 0.3669 - val_accuracy: 0.9951
# Epoch 53/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5006 - accuracy: 0.9141
# Epoch 53: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4771 - accuracy: 0.9054 - val_loss: 0.3509 - val_accuracy: 0.9951
# Epoch 54/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5190 - accuracy: 0.8672
# Epoch 54: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4979 - accuracy: 0.8809 - val_loss: 0.3362 - val_accuracy: 0.9951
# Epoch 55/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.5079 - accuracy: 0.8359
# Epoch 55: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4709 - accuracy: 0.8907 - val_loss: 0.3222 - val_accuracy: 0.9951
# Epoch 56/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4578 - accuracy: 0.8828
# Epoch 56: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4560 - accuracy: 0.8858 - val_loss: 0.3083 - val_accuracy: 0.9951
# Epoch 57/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4412 - accuracy: 0.9141
# Epoch 57: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4422 - accuracy: 0.8972 - val_loss: 0.2951 - val_accuracy: 0.9951
# Epoch 58/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4689 - accuracy: 0.8672
# Epoch 58: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4192 - accuracy: 0.9038 - val_loss: 0.2829 - val_accuracy: 0.9951
# Epoch 59/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4658 - accuracy: 0.8516
# Epoch 59: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4271 - accuracy: 0.8972 - val_loss: 0.2713 - val_accuracy: 0.9951
# Epoch 60/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3890 - accuracy: 0.9375
# Epoch 60: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4169 - accuracy: 0.8956 - val_loss: 0.2601 - val_accuracy: 0.9951
# Epoch 61/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3880 - accuracy: 0.9219
# Epoch 61: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3815 - accuracy: 0.9282 - val_loss: 0.2492 - val_accuracy: 0.9951
# Epoch 62/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4258 - accuracy: 0.8984
# Epoch 62: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3803 - accuracy: 0.9168 - val_loss: 0.2385 - val_accuracy: 0.9951
# Epoch 63/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4361 - accuracy: 0.9062
# Epoch 63: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3735 - accuracy: 0.9250 - val_loss: 0.2281 - val_accuracy: 0.9951
# Epoch 64/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4032 - accuracy: 0.9141
# Epoch 64: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4033 - accuracy: 0.8858 - val_loss: 0.2192 - val_accuracy: 0.9951
# Epoch 65/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.4134 - accuracy: 0.8750
# Epoch 65: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3713 - accuracy: 0.9152 - val_loss: 0.2107 - val_accuracy: 0.9951
# Epoch 66/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3931 - accuracy: 0.8828
# Epoch 66: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3440 - accuracy: 0.9184 - val_loss: 0.2018 - val_accuracy: 0.9951
# Epoch 67/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2680 - accuracy: 0.9688
# Epoch 67: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3352 - accuracy: 0.9266 - val_loss: 0.1932 - val_accuracy: 0.9951
# Epoch 68/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3272 - accuracy: 0.9375
# Epoch 68: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3413 - accuracy: 0.9135 - val_loss: 0.1850 - val_accuracy: 0.9951
# Epoch 69/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2909 - accuracy: 0.9297
# Epoch 69: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3245 - accuracy: 0.9168 - val_loss: 0.1771 - val_accuracy: 0.9951
# Epoch 70/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3434 - accuracy: 0.9062
# Epoch 70: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3387 - accuracy: 0.9038 - val_loss: 0.1701 - val_accuracy: 0.9951
# Epoch 71/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3324 - accuracy: 0.8906
# Epoch 71: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3186 - accuracy: 0.9201 - val_loss: 0.1635 - val_accuracy: 0.9951
# Epoch 72/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3104 - accuracy: 0.9062
# Epoch 72: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3185 - accuracy: 0.9168 - val_loss: 0.1573 - val_accuracy: 0.9951
# Epoch 73/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2648 - accuracy: 0.9453
# Epoch 73: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2944 - accuracy: 0.9184 - val_loss: 0.1515 - val_accuracy: 0.9951
# Epoch 74/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2986 - accuracy: 0.9141
# Epoch 74: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2950 - accuracy: 0.9201 - val_loss: 0.1462 - val_accuracy: 0.9951
# Epoch 75/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2994 - accuracy: 0.9297
# Epoch 75: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3004 - accuracy: 0.9152 - val_loss: 0.1412 - val_accuracy: 0.9951
# Epoch 76/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3177 - accuracy: 0.9141
# Epoch 76: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3071 - accuracy: 0.9168 - val_loss: 0.1365 - val_accuracy: 0.9951
# Epoch 77/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3868 - accuracy: 0.8359
# Epoch 77: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3094 - accuracy: 0.9119 - val_loss: 0.1323 - val_accuracy: 0.9951
# Epoch 78/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2742 - accuracy: 0.9141
# Epoch 78: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2616 - accuracy: 0.9331 - val_loss: 0.1278 - val_accuracy: 0.9951
# Epoch 79/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3289 - accuracy: 0.9297
# Epoch 79: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2767 - accuracy: 0.9347 - val_loss: 0.1230 - val_accuracy: 0.9951
# Epoch 80/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2849 - accuracy: 0.9219
# Epoch 80: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2967 - accuracy: 0.9135 - val_loss: 0.1186 - val_accuracy: 0.9951
# Epoch 81/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2569 - accuracy: 0.9375
# Epoch 81: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2918 - accuracy: 0.9103 - val_loss: 0.1151 - val_accuracy: 0.9951
# Epoch 82/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3280 - accuracy: 0.8828
# Epoch 82: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2857 - accuracy: 0.9201 - val_loss: 0.1122 - val_accuracy: 0.9951
# Epoch 83/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2718 - accuracy: 0.9062
# Epoch 83: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2842 - accuracy: 0.9201 - val_loss: 0.1099 - val_accuracy: 0.9951
# Epoch 84/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.3146 - accuracy: 0.8906
# Epoch 84: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2719 - accuracy: 0.9168 - val_loss: 0.1072 - val_accuracy: 0.9951
# Epoch 85/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2091 - accuracy: 0.9688
# Epoch 85: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2613 - accuracy: 0.9282 - val_loss: 0.1038 - val_accuracy: 0.9951
# Epoch 86/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2812 - accuracy: 0.9141
# Epoch 86: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2595 - accuracy: 0.9217 - val_loss: 0.1010 - val_accuracy: 0.9951
# Epoch 87/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2858 - accuracy: 0.9062
# Epoch 87: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2661 - accuracy: 0.9201 - val_loss: 0.0982 - val_accuracy: 1.0000
# Epoch 88/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2733 - accuracy: 0.8984
# Epoch 88: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2855 - accuracy: 0.8972 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 89/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2243 - accuracy: 0.9453
# Epoch 89: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2464 - accuracy: 0.9347 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 90/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2619 - accuracy: 0.9297
# Epoch 90: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2407 - accuracy: 0.9315 - val_loss: 0.0912 - val_accuracy: 1.0000
# Epoch 91/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2629 - accuracy: 0.9141
# Epoch 91: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2409 - accuracy: 0.9380 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 92/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2728 - accuracy: 0.9141
# Epoch 92: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2277 - accuracy: 0.9380 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 93/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1905 - accuracy: 0.9453
# Epoch 93: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2590 - accuracy: 0.9119 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 94/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2427 - accuracy: 0.9219
# Epoch 94: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2132 - accuracy: 0.9380 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 95/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2239 - accuracy: 0.9297
# Epoch 95: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2298 - accuracy: 0.9396 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 96/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1783 - accuracy: 0.9609
# Epoch 96: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2111 - accuracy: 0.9445 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 97/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1970 - accuracy: 0.9453
# Epoch 97: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2252 - accuracy: 0.9380 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 98/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2624 - accuracy: 0.9219
# Epoch 98: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2585 - accuracy: 0.9152 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 99/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2442 - accuracy: 0.9375
# Epoch 99: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2056 - accuracy: 0.9494 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 100/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2382 - accuracy: 0.9375
# Epoch 100: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2193 - accuracy: 0.9462 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 101/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1929 - accuracy: 0.9297
# Epoch 101: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2049 - accuracy: 0.9413 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 102/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2323 - accuracy: 0.9219
# Epoch 102: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2349 - accuracy: 0.9217 - val_loss: 0.0670 - val_accuracy: 1.0000
# Epoch 103/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2234 - accuracy: 0.9219
# Epoch 103: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2496 - accuracy: 0.9201 - val_loss: 0.0657 - val_accuracy: 1.0000
# Epoch 104/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2067 - accuracy: 0.9453
# Epoch 104: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2112 - accuracy: 0.9315 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 105/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2568 - accuracy: 0.9062
# Epoch 105: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2154 - accuracy: 0.9429 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 106/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1679 - accuracy: 0.9609
# Epoch 106: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2325 - accuracy: 0.9217 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 107/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2581 - accuracy: 0.9062
# Epoch 107: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2199 - accuracy: 0.9299 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 108/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1763 - accuracy: 0.9453
# Epoch 108: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1915 - accuracy: 0.9413 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 109/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2169 - accuracy: 0.9297
# Epoch 109: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2054 - accuracy: 0.9331 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 110/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1858 - accuracy: 0.9609
# Epoch 110: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1699 - accuracy: 0.9576 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 111/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2118 - accuracy: 0.9219
# Epoch 111: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2108 - accuracy: 0.9266 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 112/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1780 - accuracy: 0.9453
# Epoch 112: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1782 - accuracy: 0.9462 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 113/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2473 - accuracy: 0.9062
# Epoch 113: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1951 - accuracy: 0.9413 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 114/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1410 - accuracy: 0.9688
# Epoch 114: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1943 - accuracy: 0.9429 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 115/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2287 - accuracy: 0.9375
# Epoch 115: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2035 - accuracy: 0.9429 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 116/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2242 - accuracy: 0.9219
# Epoch 116: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2137 - accuracy: 0.9380 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 117/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2341 - accuracy: 0.9062
# Epoch 117: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2102 - accuracy: 0.9347 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 118/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2409 - accuracy: 0.8984
# Epoch 118: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1815 - accuracy: 0.9396 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 119/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1849 - accuracy: 0.9531
# Epoch 119: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1800 - accuracy: 0.9445 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 120/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2353 - accuracy: 0.9062
# Epoch 120: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1995 - accuracy: 0.9299 - val_loss: 0.0508 - val_accuracy: 1.0000
# Epoch 121/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1330 - accuracy: 0.9609
# Epoch 121: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1611 - accuracy: 0.9543 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 122/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2165 - accuracy: 0.9219
# Epoch 122: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2117 - accuracy: 0.9299 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 123/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1962 - accuracy: 0.9531
# Epoch 123: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1658 - accuracy: 0.9625 - val_loss: 0.0481 - val_accuracy: 1.0000
# Epoch 124/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2158 - accuracy: 0.9453
# Epoch 124: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1838 - accuracy: 0.9478 - val_loss: 0.0473 - val_accuracy: 1.0000
# Epoch 125/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1969 - accuracy: 0.9141
# Epoch 125: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1924 - accuracy: 0.9364 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 126/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1660 - accuracy: 0.9453
# Epoch 126: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1992 - accuracy: 0.9331 - val_loss: 0.0464 - val_accuracy: 1.0000
# Epoch 127/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1510 - accuracy: 0.9297
# Epoch 127: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1569 - accuracy: 0.9494 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 128/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1384 - accuracy: 0.9609
# Epoch 128: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1871 - accuracy: 0.9413 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 129/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1853 - accuracy: 0.9297
# Epoch 129: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1840 - accuracy: 0.9347 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 130/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2212 - accuracy: 0.9453
# Epoch 130: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1753 - accuracy: 0.9462 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 131/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1817 - accuracy: 0.9531
# Epoch 131: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1824 - accuracy: 0.9429 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 132/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1563 - accuracy: 0.9375
# Epoch 132: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1541 - accuracy: 0.9462 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 133/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1764 - accuracy: 0.9375
# Epoch 133: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1755 - accuracy: 0.9413 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 134/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2220 - accuracy: 0.9453
# Epoch 134: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2120 - accuracy: 0.9347 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 135/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1329 - accuracy: 0.9609
# Epoch 135: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1806 - accuracy: 0.9445 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 136/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1824 - accuracy: 0.9453
# Epoch 136: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1756 - accuracy: 0.9364 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 137/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2054 - accuracy: 0.9141
# Epoch 137: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1692 - accuracy: 0.9429 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 138/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1595 - accuracy: 0.9609
# Epoch 138: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1782 - accuracy: 0.9429 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 139/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1855 - accuracy: 0.9375
# Epoch 139: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1888 - accuracy: 0.9331 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 140/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1450 - accuracy: 0.9609
# Epoch 140: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1653 - accuracy: 0.9511 - val_loss: 0.0385 - val_accuracy: 1.0000
# Epoch 141/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1567 - accuracy: 0.9531
# Epoch 141: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1762 - accuracy: 0.9445 - val_loss: 0.0383 - val_accuracy: 1.0000
# Epoch 142/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1721 - accuracy: 0.9375
# Epoch 142: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1702 - accuracy: 0.9413 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 143/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1109 - accuracy: 0.9688
# Epoch 143: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1610 - accuracy: 0.9445 - val_loss: 0.0375 - val_accuracy: 1.0000
# Epoch 144/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1377 - accuracy: 0.9531
# Epoch 144: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1555 - accuracy: 0.9560 - val_loss: 0.0371 - val_accuracy: 1.0000
# Epoch 145/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2333 - accuracy: 0.9297
# Epoch 145: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1857 - accuracy: 0.9380 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 146/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1892 - accuracy: 0.9297
# Epoch 146: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1842 - accuracy: 0.9380 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 147/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1782 - accuracy: 0.9531
# Epoch 147: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1841 - accuracy: 0.9413 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 148/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1770 - accuracy: 0.9453
# Epoch 148: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1570 - accuracy: 0.9543 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 149/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1684 - accuracy: 0.9453
# Epoch 149: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1830 - accuracy: 0.9380 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 150/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1154 - accuracy: 0.9766
# Epoch 150: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1651 - accuracy: 0.9462 - val_loss: 0.0358 - val_accuracy: 1.0000
# Epoch 151/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1520 - accuracy: 0.9531
# Epoch 151: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1453 - accuracy: 0.9592 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 152/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2182 - accuracy: 0.9062
# Epoch 152: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1630 - accuracy: 0.9462 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 153/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1861 - accuracy: 0.9375
# Epoch 153: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1476 - accuracy: 0.9543 - val_loss: 0.0344 - val_accuracy: 1.0000
# Epoch 154/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1307 - accuracy: 0.9609
# Epoch 154: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1585 - accuracy: 0.9445 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 155/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1045 - accuracy: 0.9766
# Epoch 155: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1552 - accuracy: 0.9576 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 156/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1883 - accuracy: 0.9219
# Epoch 156: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1704 - accuracy: 0.9413 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 157/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1537 - accuracy: 0.9688
# Epoch 157: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1443 - accuracy: 0.9592 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 158/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1758 - accuracy: 0.9453
# Epoch 158: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1586 - accuracy: 0.9560 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 159/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1521 - accuracy: 0.9609
# Epoch 159: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1609 - accuracy: 0.9413 - val_loss: 0.0324 - val_accuracy: 1.0000
# Epoch 160/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2106 - accuracy: 0.8984
# Epoch 160: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1569 - accuracy: 0.9396 - val_loss: 0.0321 - val_accuracy: 1.0000
# Epoch 161/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2118 - accuracy: 0.9219
# Epoch 161: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1586 - accuracy: 0.9429 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 162/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1696 - accuracy: 0.9453
# Epoch 162: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1602 - accuracy: 0.9494 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 163/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1634 - accuracy: 0.9375
# Epoch 163: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1611 - accuracy: 0.9462 - val_loss: 0.0310 - val_accuracy: 1.0000
# Epoch 164/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1815 - accuracy: 0.9219
# Epoch 164: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1616 - accuracy: 0.9413 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 165/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1897 - accuracy: 0.9219
# Epoch 165: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1755 - accuracy: 0.9364 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 166/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1433 - accuracy: 0.9453
# Epoch 166: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1631 - accuracy: 0.9445 - val_loss: 0.0308 - val_accuracy: 1.0000
# Epoch 167/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1516 - accuracy: 0.9453
# Epoch 167: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1559 - accuracy: 0.9478 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 168/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1508 - accuracy: 0.9375
# Epoch 168: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1800 - accuracy: 0.9331 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 169/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1464 - accuracy: 0.9531
# Epoch 169: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1432 - accuracy: 0.9576 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 170/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1293 - accuracy: 0.9531
# Epoch 170: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1276 - accuracy: 0.9625 - val_loss: 0.0293 - val_accuracy: 1.0000
# Epoch 171/1000
# ...
# Epoch 249/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0863 - accuracy: 0.9609
# Epoch 249: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1291 - accuracy: 0.9494 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 250/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1718 - accuracy: 0.9375
# Epoch 250: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1197 - accuracy: 0.9560 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 251/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0858 - accuracy: 0.9609
# Epoch 251: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1199 - accuracy: 0.9494 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 252/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1103 - accuracy: 0.9688
# Epoch 252: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1260 - accuracy: 0.9511 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 253/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0736 - accuracy: 0.9766
# Epoch 253: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1356 - accuracy: 0.9560 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 254/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1367 - accuracy: 0.9531
# Epoch 254: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1211 - accuracy: 0.9592 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 255/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1752 - accuracy: 0.9375
# Epoch 255: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1312 - accuracy: 0.9543 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 256/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0777 - accuracy: 0.9766
# Epoch 256: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1525 - accuracy: 0.9527 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 257/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0982 - accuracy: 0.9688
# Epoch 257: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1119 - accuracy: 0.9690 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 258/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0854 - accuracy: 0.9766
# Epoch 258: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1002 - accuracy: 0.9657 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 259/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0525 - accuracy: 0.9766
# Epoch 259: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1075 - accuracy: 0.9641 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 260/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1444 - accuracy: 0.9609
# Epoch 260: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1037 - accuracy: 0.9657 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 261/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1484 - accuracy: 0.9453
# Epoch 261: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1202 - accuracy: 0.9511 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 262/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1316 - accuracy: 0.9531
# Epoch 262: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1237 - accuracy: 0.9494 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 263/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0724 - accuracy: 0.9844
# Epoch 263: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1134 - accuracy: 0.9674 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 264/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1100 - accuracy: 0.9688
# Epoch 264: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1396 - accuracy: 0.9527 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 265/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0986 - accuracy: 0.9609
# Epoch 265: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1254 - accuracy: 0.9592 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 266/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1049 - accuracy: 0.9453
# Epoch 266: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1286 - accuracy: 0.9527 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 267/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1517 - accuracy: 0.9609
# Epoch 267: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1218 - accuracy: 0.9625 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 268/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1596 - accuracy: 0.9609
# Epoch 268: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1275 - accuracy: 0.9543 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 269/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0960 - accuracy: 0.9609
# Epoch 269: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1199 - accuracy: 0.9592 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 270/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0711 - accuracy: 0.9844
# Epoch 270: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1285 - accuracy: 0.9494 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 271/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1471 - accuracy: 0.9375
# Epoch 271: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1267 - accuracy: 0.9543 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 272/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0469 - accuracy: 0.9922
# Epoch 272: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1013 - accuracy: 0.9657 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 273/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2066 - accuracy: 0.9219
# Epoch 273: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1459 - accuracy: 0.9478 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 274/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1189 - accuracy: 0.9453
# Epoch 274: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0994 - accuracy: 0.9608 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 275/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0906 - accuracy: 0.9609
# Epoch 275: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1173 - accuracy: 0.9560 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 276/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1656 - accuracy: 0.9375
# Epoch 276: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1580 - accuracy: 0.9445 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 277/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1355 - accuracy: 0.9609
# Epoch 277: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1440 - accuracy: 0.9527 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 278/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1797 - accuracy: 0.9297
# Epoch 278: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1500 - accuracy: 0.9478 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 279/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1241 - accuracy: 0.9453
# Epoch 279: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1032 - accuracy: 0.9527 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 280/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1226 - accuracy: 0.9531
# Epoch 280: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0979 - accuracy: 0.9657 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 281/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0686 - accuracy: 0.9844
# Epoch 281: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1108 - accuracy: 0.9657 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 282/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1121 - accuracy: 0.9375
# Epoch 282: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1271 - accuracy: 0.9445 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 283/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1935 - accuracy: 0.9219
# Epoch 283: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1301 - accuracy: 0.9445 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 284/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0836 - accuracy: 0.9844
# Epoch 284: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1116 - accuracy: 0.9625 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 285/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1357 - accuracy: 0.9531
# Epoch 285: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1210 - accuracy: 0.9527 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 286/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2131 - accuracy: 0.9219
# Epoch 286: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1405 - accuracy: 0.9543 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 287/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1680 - accuracy: 0.9375
# Epoch 287: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1062 - accuracy: 0.9690 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 288/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1479 - accuracy: 0.9219
# Epoch 288: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1235 - accuracy: 0.9478 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 289/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2556 - accuracy: 0.9062
# Epoch 289: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1494 - accuracy: 0.9413 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 290/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1198 - accuracy: 0.9375
# Epoch 290: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1206 - accuracy: 0.9560 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 291/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1141 - accuracy: 0.9531
# Epoch 291: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1343 - accuracy: 0.9494 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 292/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1139 - accuracy: 0.9688
# Epoch 292: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1268 - accuracy: 0.9511 - val_loss: 0.0167 - val_accuracy: 1.0000
# Epoch 293/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1269 - accuracy: 0.9453
# Epoch 293: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1140 - accuracy: 0.9527 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 294/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2720 - accuracy: 0.9141
# Epoch 294: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1719 - accuracy: 0.9396 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 295/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1547 - accuracy: 0.9609
# Epoch 295: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1560 - accuracy: 0.9511 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 296/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0691 - accuracy: 0.9844
# Epoch 296: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1074 - accuracy: 0.9690 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 297/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1308 - accuracy: 0.9609
# Epoch 297: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1294 - accuracy: 0.9592 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 298/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1388 - accuracy: 0.9531
# Epoch 298: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1409 - accuracy: 0.9429 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 299/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1365 - accuracy: 0.9375
# Epoch 299: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1153 - accuracy: 0.9592 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 300/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1861 - accuracy: 0.9219
# Epoch 300: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1262 - accuracy: 0.9608 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 301/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1377 - accuracy: 0.9609
# Epoch 301: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1399 - accuracy: 0.9560 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 302/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0905 - accuracy: 0.9609
# Epoch 302: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1070 - accuracy: 0.9674 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 303/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1576 - accuracy: 0.9375
# Epoch 303: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1335 - accuracy: 0.9478 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 304/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.1499 - accuracy: 0.9531
# Epoch 304: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1303 - accuracy: 0.9560 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 305/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0794 - accuracy: 0.9766
# Epoch 305: saving model to .\gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0871 - accuracy: 0.9723 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 305: early stopping
# 1/1 [==============================] - 0s 90ms/step
# [0.9565353  0.02075455 0.02271018]
# 0

# %%
model = tf.keras.models.load_model(model_save_path)
tflite_save_path = './gesture_classifier.tflite'

# モデルを変換(量子化)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)

interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# INFO:tensorflow:Assets written to: C:\Users\ao42a\AppData\Local\Temp\tmpk436aui4\assets
# INFO:tensorflow:Assets written to: C:\Users\ao42a\AppData\Local\Temp\tmpk436aui4\assets

# %%
# chapter06.py
# -*- coding: utf-8 -*-
import csv
import copy
import itertools
from collections import deque

import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf


# ランドマークの画像上の位置を算出する関数
def calc_landmark_list(image, landmarks):
    landmark_point = []
    image_width, image_height = image.shape[1], image.shape[0]

    for _, landmark in enumerate(landmarks.landmark):
        landmark_x = min(int(landmark.x * image_width), image_width - 1)
        landmark_y = min(int(landmark.y * image_height), image_height - 1)
        landmark_point.append([landmark_x, landmark_y])

    return landmark_point


# 座標履歴を描画する関数
def draw_point_history(image, point_history):
    for index, point in enumerate(point_history):
        if point[0] != 0 and point[1] != 0:
            cv2.circle(image, (point[0], point[1]), 1 + int(index / 2),
                       (255, 0, 0), 2)
    return image


def pre_process_point_history(image, point_history):
    image_width, image_height = image.shape[1], image.shape[0]

    temp_point_history = copy.deepcopy(point_history)

    # 相対座標に変換
    base_x, base_y = 0, 0
    for index, point in enumerate(temp_point_history):
        if index == 0:
            base_x, base_y = point[0], point[1]

        temp_point_history[index][0] = (temp_point_history[index][0] -
                                        base_x) / image_width
        temp_point_history[index][1] = (temp_point_history[index][1] -
                                        base_y) / image_height

    # 1次元リストに変換
    temp_point_history = list(
        itertools.chain.from_iterable(temp_point_history))

    del temp_point_history[0:2]

    return temp_point_history


# カメラキャプチャ設定
camera_no = 0
video_capture = cv2.VideoCapture(camera_no)
video_capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
video_capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 360)

# MediaPipe Hands初期化
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils

hands = mp_hands.Hands(
    max_num_hands=1,  # 最大手検出数：1
    min_detection_confidence=0.5,  # 検出信頼度閾値：0.5
    min_tracking_confidence=0.5  # トラッキング信頼度閾値：0.5
)

# ジェスチャー認識用モデルロード
tflite_save_path = './gesture_classifier.tflite'
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# 人差指のID
ID_FINGER_TIP = 8

# 人差指の指先の座標履歴を保持するための変数
history_length = 16
point_history = deque(maxlen=history_length)
gesture_label = ['Stop', 'Clockwise', 'Counter Clockwise']

while video_capture.isOpened():
    # カメラ画像取得
    ret, frame = video_capture.read()
    if ret is False:
        break
    frame_width, frame_height = frame.shape[1], frame.shape[0]

    # 鏡映しになるよう反転
    frame = cv2.flip(frame, 1)

    # MediaPipeで扱う画像は、OpenCVのBGRの並びではなくRGBのため変換
    rgb_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # 画像をリードオンリーにしてHands検出処理実施
    rgb_image.flags.writeable = False
    hands_results = hands.process(rgb_image)
    rgb_image.flags.writeable = True

    # 有効なランドマークが検出された場合、ランドマークを描画
    if hands_results.multi_hand_landmarks:
        for hand_landmarks in hands_results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(frame, hand_landmarks,
                                      mp_hands.HAND_CONNECTIONS)

            # ランドマーク座標の計算
            landmark_list = calc_landmark_list(rgb_image, hand_landmarks)
            # 人差指の指先座標を履歴に追加
            point_history.append(landmark_list[ID_FINGER_TIP])
    else:
        if len(point_history) > 0:
            point_history.popleft()

    gesture_id = 0
    if len(point_history) == history_length:
        temp_point_history = pre_process_point_history(rgb_image,
                                                       point_history)

        interpreter.set_tensor(
            input_details[0]['index'],
            np.array([temp_point_history]).astype(np.float32))
        interpreter.invoke()
        tflite_results = interpreter.get_tensor(output_details[0]['index'])

        gesture_id = np.argmax(np.squeeze(tflite_results))

    # ディスプレイ表示
    cv2.putText(frame, gesture_label[gesture_id], (10, 30),
                cv2.FONT_HERSHEY_PLAIN, 1.2, (255, 0, 0), 1, cv2.LINE_AA)
    frame = draw_point_history(frame, point_history)
    cv2.imshow('chapter06', frame)

    # キー入力(ESC:プログラム終了)
    key = cv2.waitKey(1)
    if key == 27:  # ESC
        break

# リソースの解放
video_capture.release()
hands.close()
cv2.destroyAllWindows()
